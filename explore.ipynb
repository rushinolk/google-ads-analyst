# %%
import pandas as pd

# %%
path_google = "data/GoogleAds_DataAnalytics_Sales_Uncleaned.csv"

# %%
df = pd.read_csv(path_google)
print(df.head())
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       $1892  2024-11-16  hyderabad  desktop
# 1          8.0            0.046       $1679  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       $1624  2024/11/16  hyderabad  Desktop
# 3          6.0              NaN       $1225  2024-11-26  HYDERABAD   tablet
# 4          8.0              NaN       $1091  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# ...

# %%
df.tail()
# Out:
#       Ad_ID         Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 2595  A3595   DataAnalyticsCourse    88.0       5344.0  $242.07   17.0
# 2596  A3596   DataAnalyticsCourse   154.0       3211.0  $248.28   14.0
# 2597  A3597   Data Anlytics Corse   113.0       3808.0  $233.25   18.0
# 2598  A3598  Data Analytics Corse   196.0       5853.0  $220.13   16.0
# 2599  A3599  Data Analytics Corse     NaN       5453.0      NaN   12.0
#
#       Conversions  Conversion Rate Sale_Amount     Ad_Date   Location  \
# 2595          9.0            0.054       $1418  29-11-2024  HYDERABAD
# 2596          6.0            0.039       $1950  2024/11/28  hyderabad
# 2597          4.0            0.035       $1085  2024-11-02   Hyderbad
# 2598          7.0            0.036       $1558  2024-11-08   hydrebad
# 2599          5.0              NaN       $1174  2024/11/22  HYDERABAD
#
#        Device                 Keyword
# 2595   MOBILE    online data analytic
# 2596   TABLET   data analitics online
# ...

# %%
# Colunas nulas clicks,impressions,cost,leads,conversions,conversion rate, sale_amount
# Coluna Ad_date em str
# Coluna cost, sale_amount em str
# Colunas que são de fato str precisam de formatação para padronizar escrita
# Contar valores unicos nas colunas
# Como pode normalizar isso
# Formatar id para tirar o prefixo de texto e converter para int pode ser uma alternativa
# Preencher valores de conversion rate realizando o calculo com os valores disponiveis
# CAlcular custo por lead

# %%
# FEITO

# Extrai dados do arquivo CSV
# Retirado $ de colunas cost e sale_amount e convertendo para float
# Formata a coluna Ad_Date para o formato de data padrão
# Converção de colunas 'Clicks', 'Impressions', 'Leads', 'Conversions' para tipo numeric
# Drop na coluna conversion rate (Sera criado uma coluna calculada)
# Função orquestrando Clean e Pipeline
# Criado docker contendo bando de dados PostgreSQL
# Criado engine para conexão com o banco de dados PostgreSQL
# Main com configuração de logging e execução do pipeline
# Primeiros dados carregados e verficados no banco de dados PostgreSQL

# %%
# Pendente 

# Padronizar escrita de colunas que são de fato str
# Revisar pipeline
# Concluir CREATE TABLES do schema.sql
# Adicionar Insert de dados no schema.sql
# Adicionar README.md com instruções de uso do projeto
# Conectar Power BI com o banco de dados PostgreSQL e criar dashboards
# Criar documento de análise de dados com insights e recomendações para o cliente
